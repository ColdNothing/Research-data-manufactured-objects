# %% [markdown]
# <a href="https://colab.research.google.com/github/ColdNothing/Research-data-manufactured-objects/blob/main/Research_data_on_manufactured_objects_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ЗАГРУЗКА ТАБЛИЧНЫХ ДАННЫХ

# %%
 from google.colab import drive 
 drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Загружаем все нужные библиотеки и модули
# импортируем Pandas и Numpy

import pandas as pd
import numpy as np

# импортируем matplotlib и seaborn

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('whitegrid')
# %config InlineBackend.figure_format = 'svg' 

#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 8, 5

# %%
#создаём переменную для нашего датасета
#и смотрим первые 10 строк из него 

data_path = '/content/drive/MyDrive/Объекты BAUMHAUS.xlsx'

sales = pd.read_excel(data_path, sheet_name=1, index_col=0)

sales = sales.drop(sales.columns[[9, 10]], axis=1)

sales
# Out:
#                               2014  2015  2016  2017  2018  2019  2020  2021  \
# Бани                             0     4     6     6     3     9    10     7
# Летние домики                    1     4     4     3    52    11    10    10
# Дома 1 этаж                      2     3     2     4     7     4     9    18
# Дома 2 этажа                     3    11    11    16    15     8     7     7
# Дома общее                       5    14    13    20    22    12    16    25
# Прочее                           0     2     5     3     2     2     3     0
# Общее количество построек        6    24    28    32    79    34    39    42
# Площадь жилая двойной брус     516  1516  1194  2280  2652  1142  1229  1835
# Площадь жилая одинарный брус    52   299   159   129  1190   380   408   294
# Площадь жилая общая            568  1815  1353  2409  3842  1522  1637  2129
# Площадь дополнительная          59   237   213   253   262   150   283   282
#
#                               2022  ВСЕГО
# ...

# %%
sales = sales.T
sales
# Out:
#        Бани  Летние домики  Дома 1 этаж  Дома 2 этажа  Дома общее  Прочее  \
# 2014      0              1            2             3           5       0
# 2015      4              4            3            11          14       2
# 2016      6              4            2            11          13       5
# 2017      6              3            4            16          20       3
# 2018      3             52            7            15          22       2
# 2019      9             11            4             8          12       2
# 2020     10             10            9             7          16       3
# 2021      7             10           18             7          25       0
# 2022      1              2           10             9          19       2
# ВСЕГО    46             97           59            87         146      19
#
#        Общее количество построек  Площадь жилая двойной брус  \
# 2014                           6                         516
# ...

# %%
sales = sales.drop(sales.index[9])
sales
# Out:
#       Бани  Летние домики  Дома 1 этаж  Дома 2 этажа  Дома общее  Прочее  \
# 2014     0              1            2             3           5       0
# 2015     4              4            3            11          14       2
# 2016     6              4            2            11          13       5
# 2017     6              3            4            16          20       3
# 2018     3             52            7            15          22       2
# 2019     9             11            4             8          12       2
# 2020    10             10            9             7          16       3
# 2021     7             10           18             7          25       0
# 2022     1              2           10             9          19       2
#
#       Общее количество построек  Площадь жилая двойной брус  \
# 2014                          6                         516
# 2015                         24                        1516
# ...

# %% [markdown]
# #АНАЛИЗ ДАННЫХ БЕЗ ВИЗУАЛИЗАЦИИ

# %%
# названия столбцов
sales.columns
# Out:
# Index(['Бани', 'Летние домики', 'Дома 1 этаж', 'Дома 2 этажа', 'Дома общее',
#        'Прочее', 'Общее количество построек', 'Площадь жилая двойной брус',
#        'Площадь жилая одинарный брус', 'Площадь жилая общая',
#        'Площадь дополнительная'],
#       dtype='object')

# %%
# информация по датасету 
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 2014 to 2022
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Бани                          9 non-null      int64
#  1   Летние домики                 9 non-null      int64
#  2   Дома 1 этаж                   9 non-null      int64
#  3   Дома 2 этажа                  9 non-null      int64
#  4   Дома общее                    9 non-null      int64
#  5   Прочее                        9 non-null      int64
#  6   Общее количество построек     9 non-null      int64
#  7   Площадь жилая двойной брус    9 non-null      int64
#  8   Площадь жилая одинарный брус  9 non-null      int64
#  9   Площадь жилая общая           9 non-null      int64
#  10  Площадь дополнительная        9 non-null      int64
# dtypes: int64(11)
# memory usage: 864.0+ bytes

# %%
#статистика по числовым данным
sales.describe()
# Out:
#             Бани  Летние домики  Дома 1 этаж  Дома 2 этажа  Дома общее  \
# count   9.000000       9.000000     9.000000      9.000000    9.000000
# mean    5.111111      10.777778     6.555556      9.666667   16.222222
# std     3.407508      15.912085     5.198825      4.092676    6.036923
# min     0.000000       1.000000     2.000000      3.000000    5.000000
# 25%     3.000000       3.000000     3.000000      7.000000   13.000000
# 50%     6.000000       4.000000     4.000000      9.000000   16.000000
# 75%     7.000000      10.000000     9.000000     11.000000   20.000000
# max    10.000000      52.000000    18.000000     16.000000   25.000000
#
#          Прочее  Общее количество построек  Площадь жилая двойной брус  \
# count  9.000000                   9.000000                    9.000000
# mean   2.111111                  34.222222                 1580.111111
# std    1.536591                  19.803900                  650.112576
# ...

# %%
#средние исторические значения продаж 

round(sales.mean(),2)
# Out:
# Бани                               5.11
# Летние домики                     10.78
# Дома 1 этаж                        6.56
# Дома 2 этажа                       9.67
# Дома общее                        16.22
# Прочее                             2.11
# Общее количество построек         34.22
# Площадь жилая двойной брус      1580.11
# Площадь жилая одинарный брус     334.33
# Площадь жилая общая             1914.44
# Площадь дополнительная           222.89
# dtype: float64

# %% [markdown]
# #Визуализация данных c Python

# %%
sales.columns
# Out:
# Index(['Бани', 'Летние домики', 'Дома 1 этаж', 'Дома 2 этажа', 'Дома общее',
#        'Прочее', 'Общее количество построек', 'Площадь жилая двойной брус',
#        'Площадь жилая одинарный брус', 'Площадь жилая общая',
#        'Площадь дополнительная'],
#       dtype='object')

# %%
sales
# Out:
#       Бани  Летние домики  Дома 1 этаж  Дома 2 этажа  Дома общее  Прочее  \
# 2014     0              1            2             3           5       0
# 2015     4              4            3            11          14       2
# 2016     6              4            2            11          13       5
# 2017     6              3            4            16          20       3
# 2018     3             52            7            15          22       2
# 2019     9             11            4             8          12       2
# 2020    10             10            9             7          16       3
# 2021     7             10           18             7          25       0
# 2022     1              2           10             9          19       2
#
#       Общее количество построек  Площадь жилая двойной брус  \
# 2014                          6                         516
# 2015                         24                        1516
# ...

# %%
#количество проданных домокомплектов 

numbers_df = sales[['Бани'] + ['Летние домики'] + ['Дома 1 этаж'] + ['Дома 2 этажа'] + ['Дома общее'] + ['Прочее'] + ['Общее количество построек'] ]
numbers_df.plot();

# %%
#количество проданных домокомплектов домов

numbers_df = sales[['Дома 1 этаж'] + ['Дома 2 этажа'] + ['Дома общее'] ]
numbers_df.plot();

# %%
#количество проданных домокомлектов бань и летних домиков

numbers_df = sales[['Бани'] + ['Летние домики']]
numbers_df.plot();

# %%
#общее количество проданных домокомплектов 

numbers_df = sales['Общее количество построек']
numbers_df.plot();

# %%
#в жилой площади 

numbers_df = sales[['Площадь жилая двойной брус'] + ['Площадь жилая одинарный брус'] + ['Площадь жилая общая'] + ['Площадь дополнительная']]
numbers_df.plot();

# %%
numbers_df = sales[['Бани'] + ['Летние домики'] + ['Дома 1 этаж'] + ['Дома 2 этажа'] + ['Дома общее'] + ['Прочее'] + ['Общее количество построек'] ]
numbers_df.plot(kind='bar');

# %%
#в жилой площади 

numbers_df = sales[['Площадь жилая двойной брус'] + ['Площадь жилая одинарный брус'] + ['Площадь жилая общая'] + ['Площадь дополнительная']]
numbers_df.plot(kind='bar');
